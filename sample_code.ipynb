# %% [markdown]
# #### Sample Code for Pachinko Allocation Model (PAM)

# %%
import pandas as pd

from sklearn.decomposition import LatentDirichletAllocation
from sklearn.datasets import make_multilabel_classification

import sys
sys.path.append('C:/github/PAM_Cython')
from pam_cython import pam
# Out:
# c:\github\PAM_Cython\pam_cython
# !! Pachinko Allocation Model!!

# %% [markdown]
# ***
# ##### Toy data preparation
# - More information is availabel in the [LDA repository](https://github.com/lda-project/lda).
# - Samples (titles) are in row and vocabularies are in columns.

# %%
import lda
import lda.datasets

X = lda.datasets.load_reuters()
vocab = lda.datasets.load_reuters_vocab()
titles = lda.datasets.load_reuters_titles()
X.shape
X_df = pd.DataFrame(X,index=titles,columns=vocab)

# %% [markdown]
# ***
# ##### Conduct PAM

# %%
S=2
K=5
dat = pam.PAM(S=S,K=K,alpha0=0.01,alpha1=0.01,beta=0.1,random_state=123)
dat.freq_df2bw(freq_df=X_df)
dat.set_params(seed_topics={},initial_conf=1.0)
dat.inference()

# %% [markdown]
# ***
# ##### Summarize the results

# %% [markdown]
# 1. The document-topic distributions are available in model.thea0 and model.theta1

# %%
upper_doc_topic = pd.DataFrame(dat.get_theta0(),index=X_df.index,columns=['Topic {}'.format(i) for i in range(S)])
lower_doc_topic = pd.DataFrame(dat.get_theta1(),index=X_df.index,columns=['Topic {}'.format(i) for i in range(K)])
display(upper_doc_topic)
display(lower_doc_topic)
# Out:
#                                                      Topic 0   Topic 1
# 0 UK: Prince Charles spearheads British royal r...  0.385984  0.614016
# 1 GERMANY: Historic Dresden church rising from ...  0.639667  0.360333
# 2 INDIA: Mother Teresa's condition said still u...  0.624453  0.375547
# 3 UK: Palace warns British weekly over Charles ...  0.570036  0.429964
# 4 INDIA: Mother Teresa, slightly stronger, bles...  0.427519  0.572481
# ...                                                      ...       ...
# 390 CANADA: FEATURE - French-speaking Quebec ce...  0.601715  0.398285
# 391 BULGARIA: FEATURE - Bulgarian opera stars a...  0.500000  0.500000
# 392 USA: Fans end Elvis Presley fete with conce...  0.374224  0.625776
# 393 UK: Volcano buries studio where rock legend...  0.488690  0.511310
# 394 USA: Joseph Vostal, ex-Kidder muni banker, ...  0.389005  0.610995
#
# [395 rows x 2 columns]
#                                                      Topic 0   Topic 1  \
# 0 UK: Prince Charles spearheads British royal r...  0.197374  0.298069
# 1 GERMANY: Historic Dresden church rising from ...  0.161880  0.139886
# 2 INDIA: Mother Teresa's condition said still u...  0.198316  0.202527
# 3 UK: Palace warns British weekly over Charles ...  0.251108  0.145035
# 4 INDIA: Mother Teresa, slightly stronger, bles...  0.152489  0.156200
# ...                                                      ...       ...
# 390 CANADA: FEATURE - French-speaking Quebec ce...  0.199136  0.311491
# 391 BULGARIA: FEATURE - Bulgarian opera stars a...  0.204220  0.176090
# 392 USA: Fans end Elvis Presley fete with conce...  0.264348  0.245042
# 393 UK: Volcano buries studio where rock legend...  0.086184  0.185547
# 394 USA: Joseph Vostal, ex-Kidder muni banker, ...  0.276909  0.139571
#
#                                                      Topic 2   Topic 3  \
# 0 UK: Prince Charles spearheads British royal r...  0.162348  0.149214
# 1 GERMANY: Historic Dresden church rising from ...  0.264511  0.205865
# 2 INDIA: Mother Teresa's condition said still u...  0.282558  0.168830
# 3 UK: Palace warns British weekly over Charles ...  0.226999  0.169143
# 4 INDIA: Mother Teresa, slightly stronger, bles...  0.156200  0.223013
# ...                                                      ...       ...
# 390 CANADA: FEATURE - French-speaking Quebec ce...  0.263956  0.151601
# 391 BULGARIA: FEATURE - Bulgarian opera stars a...  0.225315  0.207735
# 392 USA: Fans end Elvis Presley fete with conce...  0.199999  0.071307
# 393 UK: Volcano buries studio where rock legend...  0.185547  0.348142
# 394 USA: Joseph Vostal, ex-Kidder muni banker, ...  0.249436  0.057176
#
#                                                      Topic 4
# 0 UK: Prince Charles spearheads British royal r...  0.192995
# 1 GERMANY: Historic Dresden church rising from ...  0.227858
# 2 INDIA: Mother Teresa's condition said still u...  0.147770
# 3 UK: Palace warns British weekly over Charles ...  0.207715
# 4 INDIA: Mother Teresa, slightly stronger, bles...  0.312098
# ...                                                      ...
# 390 CANADA: FEATURE - French-speaking Quebec ce...  0.073817
# 391 BULGARIA: FEATURE - Bulgarian opera stars a...  0.186639
# 392 USA: Fans end Elvis Presley fete with conce...  0.219305
# 393 UK: Volcano buries studio where rock legend...  0.194581
# 394 USA: Joseph Vostal, ex-Kidder muni banker, ...  0.276907
#
# [395 rows x 5 columns]

# %% [markdown]
# 2. The topic-word distributions are available in model.phi

# %%
lower_topic_word = pd.DataFrame(dat.get_phi(),index=['Topic {}'.format(i) for i in range(K)],columns = X_df.columns)
display(lower_topic_word)
# Out:
#            church      pope     years    people    mother      last      told  \
# Topic 0  0.006362  0.005612  0.004573  0.002898  0.004111  0.003476  0.003187
# Topic 1  0.007341  0.003534  0.003932  0.003250  0.003307  0.004614  0.002625
# Topic 2  0.006742  0.008021  0.004739  0.003015  0.004016  0.002681  0.002904
# Topic 3  0.005730  0.007356  0.002590  0.004272  0.004160  0.003319  0.003263
# Topic 4  0.009583  0.005709  0.005025  0.005880  0.003031  0.003829  0.004626
#
#             first     world      year  ...  novelist     smoke  sentimental  \
# Topic 0  0.002032  0.002552  0.003360  ...  0.000012  0.000012     0.000012
# Topic 1  0.002682  0.003136  0.003648  ...  0.000011  0.000011     0.000011
# Topic 2  0.003905  0.003516  0.003682  ...  0.000011  0.000178     0.000289
# Topic 3  0.003543  0.003880  0.002086  ...  0.000067  0.000123     0.000011
# Topic 4  0.004398  0.002803  0.002803  ...  0.000239  0.000011     0.000011
#
#              tale  lawrence  cristina  50-year-old  gruelling   rapidly  \
# Topic 0  0.000012  0.000300  0.000012     0.000012   0.000012  0.000012
# Topic 1  0.000011  0.000011  0.000011     0.000068   0.000011  0.000182
# Topic 2  0.000234  0.000011  0.000011     0.000011   0.000122  0.000122
# Topic 3  0.000067  0.000011  0.000236     0.000236   0.000179  0.000011
# Topic 4  0.000011  0.000011  0.000068     0.000011   0.000011  0.000011
#
#            jailed
# Topic 0  0.000069
# Topic 1  0.000239
# Topic 2  0.000011
# Topic 3  0.000011
# Topic 4  0.000011
#
# [5 rows x 4258 columns]
